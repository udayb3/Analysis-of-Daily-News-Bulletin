# %%
from youtube_transcript_api import YouTubeTranscriptApi as api

# Making a dictionary to help in storing the video id for the news video.
dit={
  # '010223':{'Morning':'','Midday':'','Evening':''},
  # '020223':{'Morning':'','Midday':'','Evening':''},
  # '030223':{'Morning':'','Midday':'','Evening':''}, 
  # '040223':{'Morning':'','Midday':'','Evening':''},
  # '050223':{'Morning':'','Midday':'','Evening':''},
  # '060223':{'Morning':'','Midday':'','Evening':''},
  # '070223':{'Morning':'','Midday':'','Evening':''},
  # '080223':{'Morning':'','Midday':'','Evening':''},
  # '090223':{'Morning':'','Midday':'','Evening':''},
  # '100223':{'Morning':'','Midday':'','Evening':''},
  # '110223':{'Morning':'','Midday':'','Evening':''},
  # '120223':{'Morning':'','Midday':'','Evening':''},
  # '130223':{'Morning':'','Midday':'','Evening':''},
  # '140223':{'Morning':'','Midday':'','Evening':''},
  # '150223':{'Morning':'','Midday':'','Evening':''},
  # '160223':{'Morning':'','Midday':'','Evening':''},
  # '170223':{'Morning':'','Midday':'','Evening':''},
  # '180223':{'Morning':'','Midday':'','Evening':''},
  # '190223':{'Morning':'','Midday':'','Evening':''},
  # '200223':{'Morning':'','Midday':'','Evening':''},
  # '210223':{'Morning':'','Midday':'','Evening':''},
  # '220223':{'Morning':'','Midday':'','Evening':''},
  # '230223':{'Morning':'','Midday':'','Evening':''},
  # '240223':{'Morning':'','Midday':'','Evening':''},
  # '250223':{'Morning':'','Midday':'','Evening':''},
  # '260223':{'Morning':'','Midday':'','Evening':''},
  # '270223':{'Morning':'','Midday':'','Evening':''},
  # '280223':{'Morning':'','Midday':'','Evening':''},
  # '010323':{'Morning':'','Midday':'','Evening':''},
  # '020323':{'Morning':'','Midday':'','Evening':''},
  # '030323':{'Morning':'','Midday':'','Evening':''}, 
  # '040323':{'Morning':'','Midday':'','Evening':''},
  # '050323':{'Morning':'','Midday':'','Evening':''},
  # '060323':{'Morning':'','Midday':'','Evening':''},
  # '070323':{'Morning':'','Midday':'','Evening':''},
  # '080323':{'Morning':'','Midday':'','Evening':''},
  # '090323':{'Morning':'','Midday':'','Evening':''},
  # '100323':{'Morning':'','Midday':'','Evening':''},
  # '110323':{'Morning':'','Midday':'','Evening':''},
  # '120323':{'Morning':'','Midday':'','Evening':''},
  # '130323':{'Morning':'','Midday':'','Evening':''},
  # '140323':{'Morning':'','Midday':'','Evening':''},
  # '150323':{'Morning':'','Midday':'','Evening':''},
  # '160323':{'Morning':'','Midday':'','Evening':''},
  # '170323':{'Morning':'','Midday':'','Evening':''},
  # '180323':{'Morning':'','Midday':'','Evening':''},
  # '190323':{'Morning':'','Midday':'','Evening':''},
  # '200323':{'Morning':'','Midday':'','Evening':''},
  # '210323':{'Morning':'','Midday':'','Evening':''},
  # '220323':{'Morning':'','Midday':'','Evening':''},
  # '230323':{'Morning':'','Midday':'','Evening':''},
  # '240323':{'Morning':'','Midday':'','Evening':''},
  # '250323':{'Morning':'','Midday':'','Evening':''},
  # '060923':{'Morning':'','Midday':'','Evening':''},
  # '070923':{'Morning':'','Midday':'','Evening':''},
  # '080923':{'Morning':'','Midday':'','Evening':''},
  # '090923':{'Morning':'','Midday':'','Evening':''},
  # '100923':{'Morning':'','Midday':'','Evening':''},
  # '110923':{'Morning':'','Midday':'','Evening':''},
  # '120923':{'Morning':'','Midday':'','Evening':''},
  # '130923':{'Morning':'','Midday':'','Evening':''},
  # '140923':{'Morning':'','Midday':'','Evening':''},
  # '150923':{'Morning':'','Midday':'','Evening':''},
  # '160923':{'Morning':'','Midday':'','Evening':''},
  # '170923':{'Morning':'','Midday':'','Evening':''},
  # '180923':{'Morning':'','Midday':'','Evening':''},
  # '190923':{'Morning':'','Midday':'','Evening':''},
  # '200923':{'Morning':'','Midday':'','Evening':''},
  # '210923':{'Morning':'','Midday':'','Evening':''},
  # '220923':{'Morning':'','Midday':'','Evening':''},
  # '230923':{'Morning':'','Midday':'','Evening':''},
  # '240923':{'Morning':'','Midday':'','Evening':''},
  # '250923':{'Morning':'','Midday':'','Evening':''},
  # '260923':{'Morning':'','Midday':'','Evening':''},
  # '270923':{'Morning':'','Midday':'','Evening':''},
  # '280923':{'Morning':'','Midday':'','Evening':''},
  # '290923':{'Morning':'','Midday':'','Evening':''},
  # '300923':{'Morning':'','Midday':'','Evening':''},
}

# This for loop gives the date as key1 and dit[key1] is the {'Morning':'','Midday':'','Evening':''} 
for key1 in dit:
  nw={}
  # Here we have use the try and except statement, if it encounters error, then it will terminate and not store any news for the given day.
  try:
    for key2 in dit[key1]:
    
      id=dit[key1][key2]
      data=api.get_transcript(id)
  
      # print(data)
      para=''
      for elm in data:
        para=para+elm['text']+' '
  
      # para
      print(para)
      nw[key2]=para
    
  except:
    print(f"\nTranscripts are disabled for {key1}. Start now from next date.")
    break
   
  with open('para.csv','a+') as obj:
    for key2 in nw:
      obj.write(f"Euro News|{key1}|{key2}|Outside India|"+nw[key2]+"\n")

# %% [markdown]
# # Now we store the data in a proper format using pandas.

# %%
import pandas as pd

df=pd.read_csv('para.csv',sep='|',names=['Channel','Date','Day-time','Place','News'])
df
# Out:
#        Channel    Date Day-time          Place  \
# 0    Euro News   10123  Morning  Outside India
# 1    Euro News   10123   Midday  Outside India
# 2    Euro News   10123  Evening  Outside India
# 3    Euro News   20123  Morning  Outside India
# 4    Euro News   20123   Midday  Outside India
# ..         ...     ...      ...            ...
# 106  Euro News  181023   Midday  Outside India
# 107  Euro News  181023  Evening  Outside India
# 108  Euro News  191023  Morning  Outside India
# 109  Euro News  191023   Midday  Outside India
# 110  Euro News  191023  Evening  Outside India
#
#                                                   News
# 0    Noble and kind these were the words used by Po...
# 1    just half an hour into 2023 Air Raid Sirens ri...
# 2    [Music] and 10 years after joining the Europea...
# 3    [Music] Brazil's president Louisiana Silva pro...
# 4    [Music] former Pope Benedict's 16th's body is ...
# ..                                                 ...
# ...
